# %% [markdown]
# <a href="https://colab.research.google.com/github/orcristales/prueba2/blob/main/prueba.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Summer camp 2026")
# Out:
# Summer camp 2026

# %%
jugador = "kirby"
jugador2 = "Shulk"
print(jugador, "ha entrado a la arena")
print(jugador2, "ha caido del escenario")
# Out:
# kirby ha entrado a la arena
# Shulk ha caido del escenario
